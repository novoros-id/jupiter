# %%
pip install deepface
# Out:
# ...
#      |████████████████████████████████| 49 kB 277 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 80 kB 1.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 216.2 MB 339 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.3 MB 626 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.7 MB 841 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 88 kB 737 kB/s eta 0:00:01
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#      |████████████████████████████████| 1.7 MB 323 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 409 kB 708 kB/s eta 0:00:01
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# ...
#      |████████████████████████████████| 440 kB 719 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 24.5 MB 265 kB/s eta 0:00:01
# ...

# %%
from deepface import DeepFace

# %%
name_file = "/Users/alexeyvaganov/Downloads/122.jpg"
obj = DeepFace.analyze(img_path=name_file, actions=['age', 'gender','emotion'])
