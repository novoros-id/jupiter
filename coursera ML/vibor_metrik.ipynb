# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing
from sklearn.datasets import load_boston
from sklearn.neighbors import KNeighborsRegressor

# %%
X,y = load_boston(return_X_y=True)

# %%
X = preprocessing.scale(X)

# %%
kf = KFold(n_splits=5,shuffle=True,random_state=42)
kf.get_n_splits(X)
# Out:
# 5

# %%
acc = 0
saveK = 0
for i in np.linspace(1, 10, num=200):
    n_ne = i 
    neigh = KNeighborsRegressor(n_neighbors=5,metric = "minkowski",weights='distance',p=n_ne)
    acc_ = cross_val_score(neigh,X,y,cv=kf)
    mean_quality = np.mean(acc_)
    if mean_quality > acc:
        acc = mean_quality
        saveK = n_ne
    print(n_ne," ",np.mean(acc_))
print(acc,saveK)
# Out:
# 1.0   0.8013825191275472
# 1.0452261306532664   0.7964902267716104
# 1.0904522613065326   0.7970351994890925
# 1.135678391959799   0.7960441449462369
# 1.1809045226130652   0.7958525038656383
# 1.2261306532663316   0.7952144445064107
# 1.271356783919598   0.7937827040268854
# 1.3165829145728645   0.7916284113617571
# 1.3618090452261307   0.7910927683768262
# 1.4070351758793969   0.7883630514366112
# 1.4522613065326633   0.7882140547442946
# 1.4974874371859297   0.7899912579171211
# 1.542713567839196   0.7892834133384248
# 1.5879396984924623   0.7935965767193268
# 1.6331658291457287   0.7917882508886473
# 1.678391959798995   0.7913626401674062
# 1.7236180904522613   0.7897891368108612
# 1.7688442211055277   0.7896838574198888
# 1.814070351758794   0.7894985303610784
# 1.8592964824120604   0.788386699049035
# 1.9045226130653266   0.7873190205017475
# 1.949748743718593   0.7879022722953434
# 1.9949748743718594   0.7887613483322593
# 2.040201005025126   0.7886295568538427
# ...

# %%
for i in np.linspace(1, 10, num=200):
    print(i)
# Out:
# 1.0
# 1.0452261306532664
# 1.0904522613065326
# 1.135678391959799
# 1.1809045226130652
# 1.2261306532663316
# 1.271356783919598
# 1.3165829145728645
# 1.3618090452261307
# 1.4070351758793969
# 1.4522613065326633
# 1.4974874371859297
# 1.542713567839196
# 1.5879396984924623
# 1.6331658291457287
# 1.678391959798995
# 1.7236180904522613
# 1.7688442211055277
# 1.814070351758794
# 1.8592964824120604
# 1.9045226130653266
# 1.949748743718593
# 1.9949748743718594
# 2.040201005025126
# 2.085427135678392
# 2.1306532663316586
# 2.1758793969849246
# 2.221105527638191
# 2.2663316582914574
# 2.3115577889447234
# 2.35678391959799
# 2.4020100502512562
# 2.4472361809045227
# 2.492462311557789
# 2.5376884422110555
# 2.582914572864322
# 2.628140703517588
# 2.6733668341708543
# 2.7185929648241207
# 2.7638190954773867
# 2.809045226130653
# 2.8542713567839195
# 2.899497487437186
# 2.9447236180904524
# 2.9899497487437188
# 3.035175879396985
# 3.080402010050251
# 3.1256281407035176
# 3.170854271356784
# ...

# %%
for i in numpy.linspace(1, 10, num=10):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-771071181c28> in <module>
# ----> 1 for i in numpy.linspace(1, 10, num=10):
#       2     print(i)
#
# NameError: name 'numpy' is not defined
