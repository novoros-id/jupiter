# %%
import pandas
data = pandas.read_csv('titanic.csv', index_col='PassengerId')

# %%
data[:10]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# ...

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
d_sex = data['Sex'].value_counts()
print(d_sex)
d_sex.to_csv("ex1.txt")
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
print(data["Pclass"].value_counts())
d_p1 = 100 / len(data.index)  * data["Pclass"].value_counts()[1]
print(d_p1)
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64
# 24.242424242424242

# %%
d_s_o = 100 / len(data.index)  * data["Survived"].value_counts()[1]
print(d_s_o)
# Out:
# 38.38383838383839

# %%
d_p1 = 100 / len(data.index)  * data["Pclass"].value_counts()[2]
print(d_p1)
# Out:
# 20.65095398428732

# %%
data.dropna(subset=['Age'], inplace=True)
d_age= data["Age"].mean()
print (d_age)
# Out:
# 29.69911764705882

# %%
d_age= data["Age"].mean()
print (d_age)
# Out:
# 29.69911764705882

# %%
d_age= data["Age"].median()
print (d_age)
# Out:
# 28.0

# %%
data.corr(method="pearson")
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
name_plus_sex = data['Name'] + ';' + data['Sex']

list = []

for name in name_plus_sex:

if name.split(';')[1] == 'female':

if '(' in name.split(';')[0]:

splitted = name.split(';')[0].split('(')[-1].split(' ')[0]

list.append(splitted)

else:

splitted_miss = name.split(';')[0].replace('Miss.','').split(',')[1]

list.append(splitted_miss)

print(list)
# Out:
#   File "<ipython-input-88-c7ab09b57c6f>", line 7
#     if name.split(';')[1] == 'female':
#      ^
# IndentationError: expected an indented block

# %%
data[["Name","Sex"]]
# Out:
#                                                           Name     Sex
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# 887                                      Montvila, Rev. Juozas    male
# 888                               Graham, Miss. Margaret Edith  female
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female
# 890                                      Behr, Mr. Karl Howell    male
# 891                                        Dooley, Mr. Patrick    male
#
# [891 rows x 2 columns]
