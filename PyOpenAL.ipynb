# %%
import time
from openal import *
# Out:
# ---------------------------------------------------------------------------
# ExternalLibraryError                      Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 import time
# ----> 2 from openal import *
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/openal/__init__.py:1, in <module>
# ----> 1 from .al import *
#       2 from .alc import *
#       4 import ctypes, warnings
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/openal/al.py:6, in <module>
#       3 import ctypes
#       4 import ctypes.util
# ----> 6 from .al_lib import lib
#       8 AL_NONE = 0
#       9 AL_FALSE = 0
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/openal/al_lib.py:12, in <module>
#       9     if lib: break
#      11 if not lib:
# ---> 12     raise ExternalLibraryError("OpenAL library couldn't be found")
#
# ExternalLibraryError: OpenAL library couldn't be found

# %%
pip install OpenAL
# Out:
# ERROR: Could not find a version that satisfies the requirement OpenAL (from versions: none)
# ERROR: No matching distribution found for OpenAL
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.4.0
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# anaconda-client               1.9.0
# anaconda-navigator            2.1.4
# anaconda-project              0.10.2
# anyio                         3.5.0
# appdirs                       1.4.4
# applaunchservices             0.2.1
# appnope                       0.1.2
# appscript                     1.1.2
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# astunparse                    1.6.3
# async-timeout                 4.0.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# ...
